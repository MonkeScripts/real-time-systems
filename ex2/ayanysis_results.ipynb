# %%
import pandas as pd
import json
import os

# test case paths
test_cases = [
    "DRTS_Project-Test-Cases-master/8-unschedulable-test-case",
    "DRTS_Project-Test-Cases-master/9-unschedulable-test-case",
    "DRTS_Project-Test-Cases-master/10-unschedulable-test-case"
]

# show all test cases
for test_case in test_cases:
    print(f"\n{'='*60}")
    print(f"Test Case: {test_case}")
    print(f"{'='*60}\n")
    
    # tasks.csv
    print("tasks.csv:")
    tasks_file = os.path.join(test_case, "tasks.csv")
    if os.path.exists(tasks_file):
        tasks_df = pd.read_csv(tasks_file)
        display(tasks_df)
    else:
        print(f"File not found: {tasks_file}")
    
    # architecture.csv
    print("\narchitecture.csv:")
    arch_file = os.path.join(test_case, "architecture.csv")
    if os.path.exists(arch_file):
        arch_df = pd.read_csv(arch_file)
        display(arch_df)
    else:
        print(f"File not found: {arch_file}")
    
    # budgets.csv
    print("\nbudgets.csv:")
    budgets_file = os.path.join(test_case, "budgets.csv")
    if os.path.exists(budgets_file):
        budgets_df = pd.read_csv(budgets_file)
        display(budgets_df)
    else:
        print(f"File not found: {budgets_file}")
    
    # analysis_results.json
    print("\nanalysis_results.json:")
    results_file = os.path.join(test_case, "analysis_results.json")
    if os.path.exists(results_file):
        with open(results_file, 'r') as f:
            results = json.load(f)
            print(json.dumps(results, indent=2))
    else:
        print(f"File not found: {results_file}")
    
    print("\n" + "="*60)
# Out:
# ...
# Test Case: DRTS_Project-Test-Cases-master/8-unschedulable-test-case
# ...
#
# tasks.csv:
#    task_name  wcet  period        component_id  priority
# 0     Task_0     1     100       Camera_Sensor       3.0
# 1     Task_1     4     300       Camera_Sensor       4.0
# 2     Task_2     1      25       Camera_Sensor       0.0
# 3     Task_3     1      50       Camera_Sensor       1.0
# 4     Task_4     1      75       Camera_Sensor       2.0
# 5     Task_5     1      25     Image_Processor       NaN
# 6     Task_6     1      20     Image_Processor       NaN
# 7     Task_7     1     100     Image_Processor       NaN
# 8     Task_8     1      50    Bitmap_Processor       1.0
# 9     Task_9     1     100    Bitmap_Processor       2.0
# 10   Task_10     1      25    Bitmap_Processor       0.0
# 11   Task_11     1     300    Bitmap_Processor       3.0
# 12   Task_12     2      25        Lidar_Sensor       1.0
# 13   Task_13     1      10        Lidar_Sensor       0.0
# ...
