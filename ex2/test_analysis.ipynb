# %%
# Import necessary libraries
import os
import json
import time
import pandas as pd
from IPython.display import display
from system import System
from analysis import Analysis

# Define the path to your test cases
# Change this path to match your actual test cases location
root_folder = "DRTS_Project-Test-Cases-master"

def analyze_all_direct(root_folder):
    #"""Directly analyze all test cases using AnalysisTool (no subprocess)"""
    # Get all test case folders
    all_folders = [d for d in os.listdir(root_folder) 
                  if os.path.isdir(os.path.join(root_folder, d)) and d[0].isdigit()]
    
    # Sort by number
    all_folders.sort(key=lambda x: int(x.split('-')[0]))
    
    print(f"Found {len(all_folders)} test cases:")
    for folder in all_folders:
        print(f"  - {folder}")
    
    results = []
    
    # Analyze each test case
    for folder in all_folders:
        test_path = os.path.join(root_folder, folder)
        
        print(f"\n{'='*60}")
        print(f"Test case: {folder}")
        print(f"{'='*60}")
        
        # Build file paths
        tasks_file = os.path.join(test_path, "tasks.csv")
        arch_file = os.path.join(test_path, "architecture.csv")
        budgets_file = os.path.join(test_path, "budgets.csv")
        
        # Check if files exist
        if not all(os.path.exists(f) for f in [tasks_file, arch_file, budgets_file]):
            print(f"Error: Test case {folder} is missing required input files")
            continue
        
        start_time = time.time()
        
        try:
            # Load system
            print(f"Loading system configuration...")
            system = System(tasks_file, arch_file, budgets_file)
            
            # Create analysis tool
            print("Initializing analysis tool...")
            analyzer = Analysis(system)
            
            # Perform analysis
            print("Running analysis...")
            analyzer.analyze()
            
            # Generate report
            print("Generating analysis report...")
            report = analyzer.generate_report()
            
            # Check if test case is expected to be unschedulable
            expected_unschedulable = "unschedulable" in folder.lower()
            actual_schedulable = report.get("system_schedulable", False)
            
            if expected_unschedulable and actual_schedulable:
                print("Warning: Test case expected to be unschedulable, but analysis shows it's schedulable")
            elif not expected_unschedulable and not actual_schedulable:
                print("Warning: Test case expected to be schedulable, but analysis shows it's not schedulable")
            
            # Save results
            results_file = os.path.join(test_path, "analysis_results.json")
            with open(results_file, 'w') as f:
                json.dump(report, f, indent=4)
            
            # Create CSV output
            solution_file = os.path.join(test_path, "solution.csv")
            create_solution_csv(report, solution_file)
            
            # Get component and task counts
            num_components = len(report.get('components', {}))
            task_count = 0
            for comp in report.get('components', {}).values():
                task_count += len(comp.get('tasks', {}))
            
            # Collect result summary
            results.append({
                "test_case": folder,
                "schedulable": actual_schedulable,
                "expected_unschedulable": expected_unschedulable,
                "match": (expected_unschedulable and not actual_schedulable) or 
                         (not expected_unschedulable and actual_schedulable),
                "components": num_components,
                "tasks": task_count,
                "time": time.time() - start_time
            })
            
            print(f"Results saved to {results_file}")
            
            # Print analysis summary for this test case
            print("\nAnalysis Summary:")
            print(f"System schedulable: {'Yes' if actual_schedulable else 'No'}")
            print(f"Expected result: {'Unschedulable' if expected_unschedulable else 'Schedulable'}")
            print(f"Analysis time: {results[-1]['time']:.2f} seconds")
            
            # Print component details
            print("\nComponent Details:")
            for comp_id, comp_info in report.get('components', {}).items():
                print(f"  Component {comp_id}: {'Schedulable' if comp_info.get('schedulable', False) else 'Not schedulable'}")
                if 'bdr_alpha' in comp_info and 'bdr_delta' in comp_info:
                    print(f"    BDR parameters: alpha={comp_info['bdr_alpha']:.3f}, delta={comp_info['bdr_delta']:.3f}")
            
        except Exception as e:
            print(f"Error analyzing {folder}: {str(e)}")
            import traceback
            traceback.print_exc()
            
            results.append({
                "test_case": folder,
                "schedulable": "Error",
                "expected_unschedulable": expected_unschedulable,
                "match": False,
                "components": "Unknown",
                "tasks": "Unknown",
                "time": time.time() - start_time,
                "error": str(e)
            })
    
    # Create and display summary table
    print("\n" + "="*100)
    print("ANALYSIS RESULTS SUMMARY")
    print("="*100)
    
    headers = ["Test Case", "Expected", "Result", "Match", "Components", "Tasks", "Time (s)"]
    rows = []
    
    for r in results:
        expected = "Unschedulable" if r["expected_unschedulable"] else "Schedulable"
        result = r["schedulable"] if isinstance(r["schedulable"], str) else ("Schedulable" if r["schedulable"] else "Unschedulable")
        match = "✓" if r["match"] else "✗"
        components = r["components"]
        tasks = r["tasks"]
        time_taken = f"{r['time']:.2f}"
        
        rows.append([r['test_case'], expected, result, match, components, tasks, time_taken])
    
    # Create and display a DataFrame for better formatting
    df = pd.DataFrame(rows, columns=headers)
    pd.set_option('display.max_rows', None)
    pd.set_option('display.width', 1000)
    display(df)
    
    # Save overall summary
    summary_file = os.path.join(root_folder, "analysis_summary.json")
    with open(summary_file, 'w') as f:
        json.dump(results, f, indent=4)
    
    print(f"\nSummary results saved to: {summary_file}")
    
    # Calculate accuracy
    valid_results = [r for r in results if not isinstance(r["schedulable"], str)]
    if valid_results:
        correct_count = sum(1 for r in valid_results if r["match"])
        accuracy = correct_count / len(valid_results) * 100
        print(f"\nAnalysis accuracy: {correct_count}/{len(valid_results)} ({accuracy:.1f}%)")
        
        # Identify any potential issues
        if accuracy < 100:
            print("\nMismatched test cases:")
            for r in valid_results:
                if not r["match"]:
                    expected = "Unschedulable" if r["expected_unschedulable"] else "Schedulable"
                    actual = "Schedulable" if r["schedulable"] else "Unschedulable"
                    print(f"  - {r['test_case']}: Expected {expected}, got {actual}")
    
    return results

def create_solution_csv(report, output_file):
    """Create solution.csv format output"""
    with open(output_file, 'w') as f:
        # Write header
        f.write("task_name,component_id,task_schedulable,avg_response_time,max_response_time,component_schedulable\n")
        
        # For each component and task in the report
        for comp_id, comp_info in report.get('components', {}).items():
            comp_schedulable = 1 if comp_info.get('schedulable', False) else 0
            
            for task_name, task_info in comp_info.get('tasks', {}).items():
                task_schedulable = 1 if task_info.get('schedulable', True) else 0
                
                # Analysis tool may not have response time info, so use 0 as placeholder
                avg_response_time = task_info.get('avg_response_time', 0)
                max_response_time = task_info.get('max_response_time', 0)
                
                f.write(f"{task_name},{comp_id},{task_schedulable},{avg_response_time},{max_response_time},{comp_schedulable}\n")

# Run the analysis function
# (Uncomment the line below to execute when ready)
results = analyze_all_direct(root_folder)
# Out:
# Found 10 test cases:
#   - 1-tiny-test-case
#   - 2-small-test-case
#   - 3-medium-test-case
#   - 4-large-test-case
#   - 5-huge-test-case
#   - 6-gigantic-test-case
#   - 7-unschedulable-test-case
#   - 8-unschedulable-test-case
#   - 9-unschedulable-test-case
#   - 10-unschedulable-test-case
#
# ============================================================
# Test case: 1-tiny-test-case
# ============================================================
# Loading system configuration...
# loaded dataframes:
#   core_id  speed_factor scheduler
# 0  Core_1          0.62        RM
#     component_id scheduler  budget  period core_id  priority
# 0  Camera_Sensor        RM      84      84  Core_1         0
#   task_name  wcet  period   component_id  priority
# 0    Task_0    14      50  Camera_Sensor         0
# 1    Task_1    33     100  Camera_Sensor         1
# Initializing analysis tool...
# Running analysis...
# Generating analysis report...
# Results saved to DRTS_Project-Test-Cases-master\1-tiny-test-case\analysis_results.json
#
# Analysis Summary:
# System schedulable: Yes
# Expected result: Schedulable
# Analysis time: 0.01 seconds
#
# Component Details:
#   Component Camera_Sensor: Schedulable
#     BDR parameters: alpha=0.994, delta=0.000
#
# ============================================================
# Test case: 2-small-test-case
# ============================================================
# Loading system configuration...
# loaded dataframes:
#   core_id  speed_factor scheduler
# 0  Core_1          0.62       EDF
#       component_id scheduler  budget  period core_id  priority
# 0    Camera_Sensor        RM       4       7  Core_1       NaN
# 1  Image_Processor       EDF       5      16  Core_1       NaN
#   task_name  wcet  period     component_id  priority
# 0    Task_0     3     150    Camera_Sensor       1.0
# 1    Task_1    28     200    Camera_Sensor       2.0
# 2    Task_2     2      50    Camera_Sensor       0.0
# 3    Task_3    24     300    Camera_Sensor       3.0
# 4    Task_4     2     200  Image_Processor       NaN
# 5    Task_5    11     200  Image_Processor       NaN
# 6    Task_6    17     400  Image_Processor       NaN
# 7    Task_7    13     300  Image_Processor       NaN
# 8    Task_8     3     150  Image_Processor       NaN
# Initializing analysis tool...
# Running analysis...
# Generating analysis report...
# Results saved to DRTS_Project-Test-Cases-master\2-small-test-case\analysis_results.json
#
# Analysis Summary:
# System schedulable: Yes
# Expected result: Schedulable
# Analysis time: 0.01 seconds
#
# Component Details:
#   Component Camera_Sensor: Schedulable
#     BDR parameters: alpha=0.532, delta=0.000
#   Component Image_Processor: Schedulable
#     BDR parameters: alpha=0.286, delta=45.000
#
# ============================================================
# Test case: 3-medium-test-case
# ============================================================
# Loading system configuration...
# loaded dataframes:
#   core_id  speed_factor scheduler
# 0  Core_1          1.49       EDF
# 1  Core_2          0.62       EDF
#       component_id scheduler  budget  period core_id  priority
# 0    Camera_Sensor        RM       5       9  Core_1       NaN
# 1  Image_Processor       EDF       2       6  Core_1       NaN
# 2     Lidar_Sensor        RM       1       3  Core_2       NaN
# 3     Control_Unit       EDF       6       9  Core_2       NaN
#    task_name  wcet  period     component_id  priority
# 0     Task_0    16     100    Camera_Sensor       1.0
# 1     Task_1    10      50    Camera_Sensor       0.0
# 2     Task_2    58     300    Camera_Sensor       3.0
# 3     Task_3     8     200    Camera_Sensor       2.0
# 4     Task_4   120     900    Camera_Sensor       4.0
# 5     Task_5     4      25  Image_Processor       NaN
# 6     Task_6     4      50  Image_Processor       NaN
# 7     Task_7    13      75  Image_Processor       NaN
# 8     Task_8     1      25     Lidar_Sensor       0.0
# 9     Task_9     4     100     Lidar_Sensor       2.0
# 10   Task_10     2      50     Lidar_Sensor       1.0
# 11   Task_11     3     200     Lidar_Sensor       3.0
# 12   Task_12     3      75     Control_Unit       NaN
# 13   Task_13     4      40     Control_Unit       NaN
# 14   Task_14     6     100     Control_Unit       NaN
# 15   Task_15     4      50     Control_Unit       NaN
# 16   Task_16     5      75     Control_Unit       NaN
# 17   Task_17     4     120     Control_Unit       NaN
# Initializing analysis tool...
# Running analysis...
# Generating analysis report...
# Results saved to DRTS_Project-Test-Cases-master\3-medium-test-case\analysis_results.json
#
# Analysis Summary:
# System schedulable: Yes
# Expected result: Schedulable
# Analysis time: 0.01 seconds
#
# Component Details:
#   Component Camera_Sensor: Schedulable
#     BDR parameters: alpha=0.498, delta=0.000
#   Component Image_Processor: Schedulable
#     BDR parameters: alpha=0.287, delta=0.000
#   Component Lidar_Sensor: Schedulable
#     BDR parameters: alpha=0.228, delta=7.500
#   Component Control_Unit: Schedulable
#     BDR parameters: alpha=0.623, delta=12.000
#
# ============================================================
# Test case: 4-large-test-case
# ============================================================
# Loading system configuration...
# loaded dataframes:
#   core_id  speed_factor scheduler
# 0  Core_1          0.54       EDF
# 1  Core_2          0.70       EDF
# 2  Core_3          0.74        RM
#          component_id scheduler  budget  period core_id  priority
# 0       Camera_Sensor        RM       4      11  Core_1       NaN
# 1     Image_Processor       EDF       2       7  Core_1       NaN
# 2    Bitmap_Processor        RM       1       7  Core_1       NaN
# 3        Lidar_Sensor        RM       1       3  Core_2       NaN
# 4        Control_Unit       EDF       4       6  Core_2       NaN
# 5          GPS_Sensor        RM       3      13  Core_3       1.0
# 6  Communication_Unit        RM       2       4  Core_3       0.0
#    task_name  wcet  period        component_id  priority
# 0     Task_0     4     400       Camera_Sensor       3.0
# 1     Task_1     8     600       Camera_Sensor       4.0
# 2     Task_2     3      75       Camera_Sensor       0.0
# 3     Task_3     2     100       Camera_Sensor       1.0
# 4     Task_4     2     150       Camera_Sensor       2.0
# 5     Task_5     2      50     Image_Processor       NaN
# 6     Task_6     4      80     Image_Processor       NaN
# 7     Task_7     2     200     Image_Processor       NaN
# 8     Task_8     6     300    Bitmap_Processor       1.0
# 9     Task_9     3     600    Bitmap_Processor       2.0
# 10   Task_10     3      75    Bitmap_Processor       0.0
# 11   Task_11     3     900    Bitmap_Processor       3.0
# 12   Task_12     8     100        Lidar_Sensor       1.0
# 13   Task_13     9      90        Lidar_Sensor       0.0
# 14   Task_14     6     300        Lidar_Sensor       2.0
# 15   Task_15    23     900        Lidar_Sensor       3.0
# 16   Task_16     2     200        Control_Unit       NaN
# 17   Task_17     7      80        Control_Unit       NaN
# 18   Task_18     4     800        Control_Unit       NaN
# 19   Task_19    12     100        Control_Unit       NaN
# 20   Task_20    37     300        Control_Unit       NaN
# 21   Task_21     4      50        Control_Unit       NaN
# 22   Task_22     6      60          GPS_Sensor       0.0
# 23   Task_23     3     300          GPS_Sensor       1.0
# 24   Task_24     3      75  Communication_Unit       1.0
# 25   Task_25     8     100  Communication_Unit       2.0
# 26   Task_26    24     300  Communication_Unit       3.0
# 27   Task_27     3      30  Communication_Unit       0.0
# Initializing analysis tool...
# Running analysis...
# Generating analysis report...
# Results saved to DRTS_Project-Test-Cases-master\4-large-test-case\analysis_results.json
#
# Analysis Summary:
# System schedulable: Yes
# Expected result: Schedulable
# Analysis time: 0.01 seconds
#
# Component Details:
#   Component Camera_Sensor: Schedulable
#     BDR parameters: alpha=0.189, delta=0.000
#   Component Image_Processor: Schedulable
#     BDR parameters: alpha=0.195, delta=15.000
#   Component Bitmap_Processor: Schedulable
#     BDR parameters: alpha=0.137, delta=22.500
#   Component Lidar_Sensor: Schedulable
#     BDR parameters: alpha=0.332, delta=0.000
#   Component Control_Unit: Schedulable
#     BDR parameters: alpha=0.618, delta=15.000
#   Component GPS_Sensor: Schedulable
#     BDR parameters: alpha=0.159, delta=0.000
#   Component Communication_Unit: Schedulable
#     BDR parameters: alpha=0.415, delta=0.000
#
# ============================================================
# Test case: 5-huge-test-case
# ============================================================
# Loading system configuration...
# loaded dataframes:
#   core_id  speed_factor scheduler
# 0  Core_1          1.21       EDF
# 1  Core_2          1.34        RM
# 2  Core_3          1.16        RM
# 3  Core_4          1.48       EDF
# 4  Core_5          0.79       EDF
# 5  Core_6          0.63       EDF
# 6  Core_7          1.39       EDF
# 7  Core_8          0.63       EDF
#           component_id scheduler  budget  period core_id  priority
# 0        Camera_Sensor        RM       2       6  Core_1       NaN
# 1      Image_Processor       EDF       4      25  Core_1       NaN
# 2     Bitmap_Processor        RM       4      18  Core_1       NaN
# 3         Lidar_Sensor        RM       1       3  Core_2       0.0
# 4         Control_Unit       EDF       3      14  Core_2       1.0
# 5           GPS_Sensor        RM       1       5  Core_3       0.0
# 6   Communication_Unit        RM       3      10  Core_3       2.0
# 7     Proximity_Sensor       EDF       2       9  Core_3       1.0
# 8         Radar_Sensor       EDF      10      19  Core_4       NaN
# 9         Sonar_Sensor        RM       2       8  Core_4       NaN
# 10        Laser_Sensor        RM       2       4  Core_5       NaN
# 11     Infrared_Sensor        RM       1       3  Core_5       NaN
# 12  Ultraviolet_Sensor       EDF       4      15  Core_6       NaN
# 13      Thermal_Sensor       EDF      17      33  Core_6       NaN
# 14     Pressure_Sensor        RM       1       7  Core_7       NaN
# 15     Humidity_Sensor        RM       8      15  Core_7       NaN
# 16  Temperature_Sensor       EDF       7      11  Core_8       NaN
# 17        Light_Sensor        RM       3      13  Core_8       NaN
#    task_name  wcet  period        component_id  priority
# 0     Task_0     3      20       Camera_Sensor       0.0
# 1     Task_1    20     120       Camera_Sensor       1.0
# 2     Task_2     8     100     Image_Processor       NaN
# 3     Task_3    10     300     Image_Processor       NaN
# 4     Task_4    10     100    Bitmap_Processor       0.0
# ..       ...   ...     ...                 ...       ...
# 56   Task_56    28     225  Temperature_Sensor       NaN
# 57   Task_57     2      80  Temperature_Sensor       NaN
# 58   Task_58     4     100        Light_Sensor       1.0
# 59   Task_59     1      50        Light_Sensor       0.0
# 60   Task_60     8     200        Light_Sensor       2.0
#
# [61 rows x 5 columns]
# Initializing analysis tool...
# Running analysis...
# Generating analysis report...
# Results saved to DRTS_Project-Test-Cases-master\5-huge-test-case\analysis_results.json
#
# Analysis Summary:
# System schedulable: Yes
# Expected result: Schedulable
# Analysis time: 0.01 seconds
#
# Component Details:
#   Component Camera_Sensor: Schedulable
#     BDR parameters: alpha=0.272, delta=0.000
#   Component Image_Processor: Schedulable
#     BDR parameters: alpha=0.104, delta=0.000
#   Component Bitmap_Processor: Schedulable
#     BDR parameters: alpha=0.200, delta=0.000
#   Component Lidar_Sensor: Schedulable
#     BDR parameters: alpha=0.279, delta=7.500
#   Component Control_Unit: Schedulable
#     BDR parameters: alpha=0.184, delta=22.500
#   Component GPS_Sensor: Schedulable
#     BDR parameters: alpha=0.096, delta=0.000
#   Component Communication_Unit: Schedulable
#     BDR parameters: alpha=0.099, delta=15.000
#   Component Proximity_Sensor: Schedulable
#     BDR parameters: alpha=0.105, delta=0.000
#   Component Radar_Sensor: Schedulable
#     BDR parameters: alpha=0.496, delta=0.000
#   Component Sonar_Sensor: Schedulable
#     BDR parameters: alpha=0.190, delta=0.000
#   Component Laser_Sensor: Schedulable
#     BDR parameters: alpha=0.411, delta=3.000
#   Component Infrared_Sensor: Schedulable
#     BDR parameters: alpha=0.263, delta=0.000
#   Component Ultraviolet_Sensor: Schedulable
#     BDR parameters: alpha=0.206, delta=30.000
#   Component Thermal_Sensor: Schedulable
#     BDR parameters: alpha=0.371, delta=0.000
#   Component Pressure_Sensor: Schedulable
#     BDR parameters: alpha=0.089, delta=0.000
#   Component Humidity_Sensor: Schedulable
#     BDR parameters: alpha=0.503, delta=0.000
#   Component Temperature_Sensor: Schedulable
#     BDR parameters: alpha=0.596, delta=12.000
#   Component Light_Sensor: Schedulable
#     BDR parameters: alpha=0.169, delta=0.000
#
# ============================================================
# Test case: 6-gigantic-test-case
# ============================================================
# Loading system configuration...
# loaded dataframes:
#     core_id  speed_factor scheduler
# 0    Core_1          1.12       EDF
# 1    Core_2          0.75        RM
# 2    Core_3          1.19        RM
# 3    Core_4          1.38       EDF
# 4    Core_5          0.93       EDF
# 5    Core_6          0.68       EDF
# 6    Core_7          0.96       EDF
# 7    Core_8          1.19       EDF
# 8    Core_9          0.62        RM
# 9   Core_10          1.46       EDF
# 10  Core_11          1.05       EDF
# 11  Core_12          0.51       EDF
# 12  Core_13          1.25        RM
# 13  Core_14          0.73       EDF
# 14  Core_15          0.62        RM
# 15  Core_16          0.99       EDF
#            component_id scheduler  budget  period  core_id  priority
# 0         Camera_Sensor        RM       4      10   Core_1       NaN
# 1       Image_Processor       EDF       2      11   Core_1       NaN
# 2      Bitmap_Processor        RM       3      10   Core_1       NaN
# 3          Lidar_Sensor        RM       5      15   Core_2       1.0
# 4          Control_Unit       EDF       4      11   Core_2       0.0
# 5            GPS_Sensor        RM       2      13   Core_3       1.0
# 6    Communication_Unit        RM       3      13   Core_3       1.0
# 7      Proximity_Sensor       EDF       1       5   Core_3       0.0
# 8          Radar_Sensor       EDF       3       5   Core_4       NaN
# 9          Sonar_Sensor        RM       5      19   Core_4       NaN
# 10         Laser_Sensor        RM       4       9   Core_5       NaN
# 11      Infrared_Sensor        RM       2       6   Core_5       NaN
# 12   Ultraviolet_Sensor       EDF       3      12   Core_6       NaN
# 13       Thermal_Sensor       EDF       1       2   Core_6       NaN
# 14      Pressure_Sensor        RM       1       8   Core_7       NaN
# 15      Humidity_Sensor        RM       2       3   Core_7       NaN
# 16   Temperature_Sensor       EDF      20      32   Core_8       NaN
# 17         Light_Sensor        RM       5      23   Core_8       NaN
# 18         Sound_Sensor        RM      14      37   Core_9       1.0
# 19     Vibration_Sensor       EDF       1       8   Core_9       0.0
# 20        Motion_Sensor        RM      17      61  Core_10       NaN
# 21  Acceleration_Sensor        RM       5      16  Core_10       NaN
# 22     Gyroscope_Sensor       EDF       3       9  Core_11       NaN
# 23  Magnetometer_Sensor        RM       1       7  Core_11       NaN
# 24       Compass_Sensor        RM       2      12  Core_12       NaN
# 25     Altimeter_Sensor       EDF       1       9  Core_12       NaN
# 26     Barometer_Sensor       EDF       5       9  Core_13       0.0
# 27    Hygrometer_Sensor        RM       6      23  Core_13       1.0
# 28    Anemometer_Sensor        RM       1       2  Core_14       NaN
# 29    Rain_Gauge_Sensor        RM       8      16  Core_14       NaN
# 30    Snow_Gauge_Sensor       EDF       3      13  Core_15       1.0
# 31   Thermometer_Sensor       EDF       6      12  Core_15       0.0
# 32     Pyrometer_Sensor        RM       1       9  Core_16       NaN
# 33    Photometer_Sensor        RM       9      15  Core_16       NaN
#     task_name  wcet  period       component_id  priority
# 0      Task_0     7      50      Camera_Sensor       1.0
# 1      Task_1     4      25      Camera_Sensor       0.0
# 2      Task_2     3      50    Image_Processor       NaN
# 3      Task_3     1      25    Image_Processor       NaN
# 4      Task_4     3      25   Bitmap_Processor       0.0
# ..        ...   ...     ...                ...       ...
# 110  Task_110     2      50   Pyrometer_Sensor       0.0
# 111  Task_111     6     300   Pyrometer_Sensor       2.0
# 112  Task_112     2     200   Pyrometer_Sensor       1.0
# 113  Task_113    20     125  Photometer_Sensor       1.0
# 114  Task_114    14      50  Photometer_Sensor       0.0
#
# [115 rows x 5 columns]
# Initializing analysis tool...
# Running analysis...
# Generating analysis report...
# Results saved to DRTS_Project-Test-Cases-master\6-gigantic-test-case\analysis_results.json
#
# Analysis Summary:
# System schedulable: Yes
# Expected result: Schedulable
# Analysis time: 0.02 seconds
#
# Component Details:
#   Component Camera_Sensor: Schedulable
#     BDR parameters: alpha=0.278, delta=0.000
#   Component Image_Processor: Schedulable
#     BDR parameters: alpha=0.099, delta=0.000
#   Component Bitmap_Processor: Schedulable
#     BDR parameters: alpha=0.189, delta=0.000
#   Component Lidar_Sensor: Schedulable
#     BDR parameters: alpha=0.237, delta=0.000
#   Component Control_Unit: Schedulable
#     BDR parameters: alpha=0.203, delta=7.500
#   Component GPS_Sensor: Schedulable
#     BDR parameters: alpha=0.088, delta=9.000
#   Component Communication_Unit: Schedulable
#     BDR parameters: alpha=0.094, delta=0.000
#   Component Proximity_Sensor: Schedulable
#     BDR parameters: alpha=0.094, delta=6.000
#   Component Radar_Sensor: Schedulable
#     BDR parameters: alpha=0.445, delta=3.000
#   Component Sonar_Sensor: Schedulable
#     BDR parameters: alpha=0.189, delta=0.000
#   Component Laser_Sensor: Schedulable
#     BDR parameters: alpha=0.361, delta=0.000
#   Component Infrared_Sensor: Schedulable
#     BDR parameters: alpha=0.268, delta=6.000
#   Component Ultraviolet_Sensor: Schedulable
#     BDR parameters: alpha=0.235, delta=15.000
#   Component Thermal_Sensor: Schedulable
#     BDR parameters: alpha=0.495, delta=3.000
#   Component Pressure_Sensor: Schedulable
#     BDR parameters: alpha=0.098, delta=15.000
#   Component Humidity_Sensor: Schedulable
#     BDR parameters: alpha=0.401, delta=0.000
#   Component Temperature_Sensor: Schedulable
#     BDR parameters: alpha=0.595, delta=0.000
#   Component Light_Sensor: Schedulable
#     BDR parameters: alpha=0.200, delta=0.000
#   Component Sound_Sensor: Schedulable
#     BDR parameters: alpha=0.319, delta=0.000
#   Component Vibration_Sensor: Schedulable
#     BDR parameters: alpha=0.107, delta=20.000
#   Component Motion_Sensor: Schedulable
#     BDR parameters: alpha=0.174, delta=0.000
#   Component Acceleration_Sensor: Schedulable
#     BDR parameters: alpha=0.291, delta=15.000
#   Component Gyroscope_Sensor: Schedulable
#     BDR parameters: alpha=0.200, delta=6.000
#   Component Magnetometer_Sensor: Schedulable
#     BDR parameters: alpha=0.105, delta=0.000
#   Component Compass_Sensor: Schedulable
#     BDR parameters: alpha=0.167, delta=22.500
#   Component Altimeter_Sensor: Schedulable
#     BDR parameters: alpha=0.103, delta=45.000
#   Component Barometer_Sensor: Schedulable
#     BDR parameters: alpha=0.474, delta=12.000
#   Component Hygrometer_Sensor: Schedulable
#     BDR parameters: alpha=0.202, delta=0.000
#   Component Anemometer_Sensor: Schedulable
#     BDR parameters: alpha=0.469, delta=3.000
#   Component Rain_Gauge_Sensor: Schedulable
#     BDR parameters: alpha=0.289, delta=7.500
#   Component Snow_Gauge_Sensor: Schedulable
#     BDR parameters: alpha=0.212, delta=15.000
#   Component Thermometer_Sensor: Schedulable
#     BDR parameters: alpha=0.306, delta=7.500
#   Component Pyrometer_Sensor: Schedulable
#     BDR parameters: alpha=0.081, delta=15.000
#   Component Photometer_Sensor: Schedulable
#     BDR parameters: alpha=0.494, delta=0.000
#
# ============================================================
# Test case: 7-unschedulable-test-case
# ============================================================
# Loading system configuration...
# loaded dataframes:
#   core_id  speed_factor scheduler
# 0  Core_1          1.14       EDF
# 1  Core_2          0.90       EDF
# 2  Core_3          0.80        RM
# 3  Core_4          1.25       EDF
#          component_id scheduler  budget  period core_id  priority
# 0       Camera_Sensor        RM       2       6  Core_1       NaN
# 1     Image_Processor       EDF       2       3  Core_1       NaN
# 2        Lidar_Sensor        RM     587     733  Core_2       NaN
# 3          GPS_Sensor        RM       1       4  Core_3       0.0
# 4  Communication_Unit        RM       3       7  Core_3       1.0
# 5    Proximity_Sensor       EDF       5      16  Core_4       NaN
#    task_name  wcet  period        component_id  priority
# 0     Task_0    12     100       Camera_Sensor       2.0
# 1     Task_1     1      20       Camera_Sensor       0.0
# 2     Task_2     3      60       Camera_Sensor       1.0
# 3     Task_3    30     300       Camera_Sensor       3.0
# 4     Task_4     1      10     Image_Processor       NaN
# 5     Task_5     2       5     Image_Processor       NaN
# 6     Task_6     9     100        Lidar_Sensor       2.0
# 7     Task_7     1      10        Lidar_Sensor       1.0
# 8     Task_8    41     200        Lidar_Sensor       3.0
# 9     Task_9   104     400        Lidar_Sensor       4.0
# 10   Task_10    50     800        Lidar_Sensor       5.0
# 11   Task_11     1       5        Lidar_Sensor       0.0
# 12   Task_12     1      25          GPS_Sensor       0.0
# 13   Task_13     7      75          GPS_Sensor       1.0
# 14   Task_14     2      20  Communication_Unit       0.0
# 15   Task_15     8     100  Communication_Unit       3.0
# 16   Task_16     2      25  Communication_Unit       1.0
# 17   Task_17     1      50  Communication_Unit       2.0
# 18   Task_18    16     100    Proximity_Sensor       NaN
# 19   Task_19    48     300    Proximity_Sensor       NaN
# 20   Task_20     1      25    Proximity_Sensor       NaN
# Initializing analysis tool...
# Running analysis...
# Generating analysis report...
# Results saved to DRTS_Project-Test-Cases-master\7-unschedulable-test-case\analysis_results.json
#
# Analysis Summary:
# System schedulable: No
# Expected result: Unschedulable
# Analysis time: 0.01 seconds
#
# Component Details:
#   Component Camera_Sensor: Schedulable
#     BDR parameters: alpha=0.291, delta=6.000
#   Component Image_Processor: Schedulable
#     BDR parameters: alpha=0.449, delta=0.000
#   Component Lidar_Sensor: Not schedulable
#     BDR parameters: alpha=1.019, delta=1.500
#   Component GPS_Sensor: Schedulable
#     BDR parameters: alpha=0.177, delta=0.000
#   Component Communication_Unit: Schedulable
#     BDR parameters: alpha=0.360, delta=0.000
#   Component Proximity_Sensor: Schedulable
#     BDR parameters: alpha=0.298, delta=7.500
#
# ============================================================
# Test case: 8-unschedulable-test-case
# ============================================================
# Loading system configuration...
# loaded dataframes:
#   core_id  speed_factor scheduler
# 0  Core_1          0.54       EDF
# 1  Core_2          0.70       EDF
# 2  Core_3          0.74        RM
#          component_id scheduler  budget  period core_id  priority
# 0       Camera_Sensor        RM       4      11  Core_1       NaN
# 1     Image_Processor       EDF       2       7  Core_1       NaN
# 2    Bitmap_Processor        RM       1       7  Core_1       NaN
# 3        Lidar_Sensor        RM       1       3  Core_2       NaN
# 4        Control_Unit       EDF       4       6  Core_2       NaN
# 5          GPS_Sensor        RM       3      13  Core_3       1.0
# 6  Communication_Unit        RM       2       4  Core_3       0.0
#    task_name  wcet  period        component_id  priority
# 0     Task_0     1     100       Camera_Sensor       3.0
# 1     Task_1     4     300       Camera_Sensor       4.0
# 2     Task_2     1      25       Camera_Sensor       0.0
# 3     Task_3     1      50       Camera_Sensor       1.0
# 4     Task_4     1      75       Camera_Sensor       2.0
# 5     Task_5     1      25     Image_Processor       NaN
# 6     Task_6     1      20     Image_Processor       NaN
# 7     Task_7     1     100     Image_Processor       NaN
# 8     Task_8     1      50    Bitmap_Processor       1.0
# 9     Task_9     1     100    Bitmap_Processor       2.0
# 10   Task_10     1      25    Bitmap_Processor       0.0
# 11   Task_11     1     300    Bitmap_Processor       3.0
# 12   Task_12     2      25        Lidar_Sensor       1.0
# 13   Task_13     1      10        Lidar_Sensor       0.0
# 14   Task_14     1      50        Lidar_Sensor       2.0
# 15   Task_15     6     150        Lidar_Sensor       3.0
# 16   Task_16     1     100        Control_Unit       NaN
# 17   Task_17     1      10        Control_Unit       NaN
# 18   Task_18     1     200        Control_Unit       NaN
# 19   Task_19     6      50        Control_Unit       NaN
# 20   Task_20    37     300        Control_Unit       NaN
# 21   Task_21     2      25        Control_Unit       NaN
# 22   Task_22     6      50          GPS_Sensor       0.0
# 23   Task_23     1     100          GPS_Sensor       1.0
# 24   Task_24     1      25  Communication_Unit       1.0
# 25   Task_25     8     100  Communication_Unit       2.0
# 26   Task_26    24     300  Communication_Unit       3.0
# 27   Task_27     1      10  Communication_Unit       0.0
# Initializing analysis tool...
# Running analysis...
# Generating analysis report...
# Warning: Test case expected to be unschedulable, but analysis shows it's schedulable
# Results saved to DRTS_Project-Test-Cases-master\8-unschedulable-test-case\analysis_results.json
#
# Analysis Summary:
# System schedulable: Yes
# Expected result: Unschedulable
# Analysis time: 0.01 seconds
#
# Component Details:
#   Component Camera_Sensor: Schedulable
#     BDR parameters: alpha=0.189, delta=7.500
#   Component Image_Processor: Schedulable
#     BDR parameters: alpha=0.195, delta=0.000
#   Component Bitmap_Processor: Schedulable
#     BDR parameters: alpha=0.146, delta=7.500
#   Component Lidar_Sensor: Schedulable
#     BDR parameters: alpha=0.353, delta=3.000
#   Component Control_Unit: Schedulable
#     BDR parameters: alpha=0.636, delta=3.000
#   Component GPS_Sensor: Schedulable
#     BDR parameters: alpha=0.186, delta=0.000
#   Component Communication_Unit: Schedulable
#     BDR parameters: alpha=0.415, delta=3.000
#
# ============================================================
# Test case: 9-unschedulable-test-case
# ============================================================
# Loading system configuration...
# loaded dataframes:
#   core_id  speed_factor scheduler
# 0  Core_1          1.21       EDF
# 1  Core_2          1.34        RM
# 2  Core_3          1.16        RM
# 3  Core_4          1.48       EDF
# 4  Core_5          0.79       EDF
# 5  Core_6          0.63       EDF
# 6  Core_7          1.39       EDF
# 7  Core_8          0.63       EDF
#           component_id scheduler  budget  period core_id  priority
# 0        Camera_Sensor        RM       2       6  Core_1       NaN
# 1      Image_Processor       EDF       4      25  Core_1       NaN
# 2     Bitmap_Processor        RM       4      18  Core_1       NaN
# 3         Lidar_Sensor        RM       1       3  Core_2       0.0
# 4         Control_Unit       EDF       3      14  Core_2       1.0
# 5           GPS_Sensor        RM       1       5  Core_3       0.0
# 6   Communication_Unit        RM       3      10  Core_3       2.0
# 7     Proximity_Sensor       EDF       2       9  Core_3       1.0
# 8         Radar_Sensor       EDF      10      19  Core_4       NaN
# 9         Sonar_Sensor        RM       2       8  Core_4       NaN
# 10        Laser_Sensor        RM       2       4  Core_5       NaN
# 11     Infrared_Sensor        RM       1       3  Core_5       NaN
# 12  Ultraviolet_Sensor       EDF       4      15  Core_6       NaN
# 13      Thermal_Sensor       EDF      17      33  Core_6       NaN
# 14     Pressure_Sensor        RM       1       7  Core_7       NaN
# 15     Humidity_Sensor        RM       8      15  Core_7       NaN
# 16  Temperature_Sensor       EDF       7      11  Core_8       NaN
# 17        Light_Sensor        RM       3      13  Core_8       NaN
#    task_name  wcet  period        component_id  priority
# 0     Task_0     3      20       Camera_Sensor       0.0
# 1     Task_1    10      60       Camera_Sensor       1.0
# 2     Task_2     8     100     Image_Processor       NaN
# 3     Task_3    10     300     Image_Processor       NaN
# 4     Task_4    10     100    Bitmap_Processor       0.0
# ..       ...   ...     ...                 ...       ...
# 56   Task_56    28     200  Temperature_Sensor       NaN
# 57   Task_57     1      40  Temperature_Sensor       NaN
# 58   Task_58     4     100        Light_Sensor       1.0
# 59   Task_59     1      50        Light_Sensor       0.0
# 60   Task_60     8     200        Light_Sensor       2.0
#
# [61 rows x 5 columns]
# Initializing analysis tool...
# Running analysis...
# Generating analysis report...
# Warning: Test case expected to be unschedulable, but analysis shows it's schedulable
# Results saved to DRTS_Project-Test-Cases-master\9-unschedulable-test-case\analysis_results.json
#
# Analysis Summary:
# System schedulable: Yes
# Expected result: Unschedulable
# Analysis time: 0.01 seconds
#
# Component Details:
#   Component Camera_Sensor: Schedulable
#     BDR parameters: alpha=0.272, delta=0.000
#   Component Image_Processor: Schedulable
#     BDR parameters: alpha=0.104, delta=0.000
#   Component Bitmap_Processor: Schedulable
#     BDR parameters: alpha=0.200, delta=0.000
#   Component Lidar_Sensor: Schedulable
#     BDR parameters: alpha=0.279, delta=0.000
#   Component Control_Unit: Schedulable
#     BDR parameters: alpha=0.199, delta=7.500
#   Component GPS_Sensor: Schedulable
#     BDR parameters: alpha=0.096, delta=0.000
#   Component Communication_Unit: Schedulable
#     BDR parameters: alpha=0.099, delta=7.500
#   Component Proximity_Sensor: Schedulable
#     BDR parameters: alpha=0.105, delta=15.000
#   Component Radar_Sensor: Schedulable
#     BDR parameters: alpha=0.496, delta=0.000
#   Component Sonar_Sensor: Schedulable
#     BDR parameters: alpha=0.190, delta=0.000
#   Component Laser_Sensor: Schedulable
#     BDR parameters: alpha=0.415, delta=3.000
#   Component Infrared_Sensor: Schedulable
#     BDR parameters: alpha=0.263, delta=0.000
#   Component Ultraviolet_Sensor: Schedulable
#     BDR parameters: alpha=0.206, delta=15.000
#   Component Thermal_Sensor: Schedulable
#     BDR parameters: alpha=0.371, delta=0.000
#   Component Pressure_Sensor: Schedulable
#     BDR parameters: alpha=0.089, delta=6.000
#   Component Humidity_Sensor: Schedulable
#     BDR parameters: alpha=0.503, delta=0.000
#   Component Temperature_Sensor: Schedulable
#     BDR parameters: alpha=0.621, delta=0.000
#   Component Light_Sensor: Schedulable
#     BDR parameters: alpha=0.169, delta=0.000
#
# ============================================================
# Test case: 10-unschedulable-test-case
# ============================================================
# Loading system configuration...
# loaded dataframes:
#     core_id  speed_factor scheduler
# 0    Core_1          1.12       EDF
# 1    Core_2          0.75        RM
# 2    Core_3          1.19        RM
# 3    Core_4          1.38       EDF
# 4    Core_5          0.93       EDF
# 5    Core_6          0.68       EDF
# 6    Core_7          0.96       EDF
# 7    Core_8          1.19       EDF
# 8    Core_9          0.62        RM
# 9   Core_10          1.46       EDF
# 10  Core_11          1.05       EDF
# 11  Core_12          0.51       EDF
# 12  Core_13          1.25        RM
# 13  Core_14          0.73       EDF
# 14  Core_15          0.62        RM
# 15  Core_16          0.99       EDF
#            component_id scheduler  budget  period  core_id  priority
# 0         Camera_Sensor        RM       4      10   Core_1       NaN
# 1       Image_Processor       EDF       2      11   Core_1       NaN
# 2      Bitmap_Processor        RM       3      10   Core_1       NaN
# 3          Lidar_Sensor        RM       5      15   Core_2       1.0
# 4          Control_Unit       EDF       4      11   Core_2       0.0
# 5            GPS_Sensor        RM       2      13   Core_3       1.0
# 6    Communication_Unit        RM       3      13   Core_3       1.0
# 7      Proximity_Sensor       EDF       1       5   Core_3       0.0
# 8          Radar_Sensor       EDF       3       5   Core_4       NaN
# 9          Sonar_Sensor        RM       5      19   Core_4       NaN
# 10         Laser_Sensor        RM       4       9   Core_5       NaN
# 11      Infrared_Sensor        RM       2       6   Core_5       NaN
# 12   Ultraviolet_Sensor       EDF       3      12   Core_6       NaN
# 13       Thermal_Sensor       EDF       1       2   Core_6       NaN
# 14      Pressure_Sensor        RM       1       8   Core_7       NaN
# 15      Humidity_Sensor        RM       2       3   Core_7       NaN
# 16   Temperature_Sensor       EDF      20      32   Core_8       NaN
# 17         Light_Sensor        RM       5      23   Core_8       NaN
# 18         Sound_Sensor        RM      14      37   Core_9       1.0
# 19     Vibration_Sensor       EDF       1       8   Core_9       0.0
# 20        Motion_Sensor        RM      17      61  Core_10       NaN
# 21  Acceleration_Sensor        RM       5      16  Core_10       NaN
# 22     Gyroscope_Sensor       EDF       3       9  Core_11       NaN
# 23  Magnetometer_Sensor        RM       1       7  Core_11       NaN
# 24       Compass_Sensor        RM       2      12  Core_12       NaN
# 25     Altimeter_Sensor       EDF       1       9  Core_12       NaN
# 26     Barometer_Sensor       EDF       5       9  Core_13       0.0
# 27    Hygrometer_Sensor        RM       6      23  Core_13       1.0
# 28    Anemometer_Sensor        RM       1       2  Core_14       NaN
# 29    Rain_Gauge_Sensor        RM       8      16  Core_14       NaN
# 30    Snow_Gauge_Sensor       EDF       3      13  Core_15       1.0
# 31   Thermometer_Sensor       EDF       6      12  Core_15       0.0
# 32     Pyrometer_Sensor        RM       1       9  Core_16       NaN
# 33    Photometer_Sensor        RM       9      15  Core_16       NaN
#     task_name  wcet  period       component_id  priority
# 0      Task_0     7      50      Camera_Sensor       1.0
# 1      Task_1     4      25      Camera_Sensor       0.0
# 2      Task_2     3      50    Image_Processor       NaN
# 3      Task_3     1      25    Image_Processor       NaN
# 4      Task_4     3      25   Bitmap_Processor       0.0
# ..        ...   ...     ...                ...       ...
# 110  Task_110     1      25   Pyrometer_Sensor       0.0
# 111  Task_111     1      50   Pyrometer_Sensor       1.0
# 112  Task_112     1     100   Pyrometer_Sensor       2.0
# 113  Task_113     8      50  Photometer_Sensor       1.0
# 114  Task_114     7      25  Photometer_Sensor       0.0
#
# [115 rows x 5 columns]
# Initializing analysis tool...
# Running analysis...
# Generating analysis report...
# Warning: Test case expected to be unschedulable, but analysis shows it's schedulable
# Results saved to DRTS_Project-Test-Cases-master\10-unschedulable-test-case\analysis_results.json
#
# Analysis Summary:
# System schedulable: Yes
# Expected result: Unschedulable
# Analysis time: 0.02 seconds
#
# Component Details:
#   Component Camera_Sensor: Schedulable
#     BDR parameters: alpha=0.278, delta=0.000
#   Component Image_Processor: Schedulable
#     BDR parameters: alpha=0.099, delta=0.000
#   Component Bitmap_Processor: Schedulable
#     BDR parameters: alpha=0.189, delta=0.000
#   Component Lidar_Sensor: Schedulable
#     BDR parameters: alpha=0.290, delta=0.000
#   Component Control_Unit: Schedulable
#     BDR parameters: alpha=0.203, delta=7.500
#   Component GPS_Sensor: Schedulable
#     BDR parameters: alpha=0.094, delta=0.000
#   Component Communication_Unit: Schedulable
#     BDR parameters: alpha=0.094, delta=0.000
#   Component Proximity_Sensor: Schedulable
#     BDR parameters: alpha=0.094, delta=6.000
#   Component Radar_Sensor: Schedulable
#     BDR parameters: alpha=0.445, delta=1.500
#   Component Sonar_Sensor: Schedulable
#     BDR parameters: alpha=0.198, delta=0.000
#   Component Laser_Sensor: Schedulable
#     BDR parameters: alpha=0.361, delta=0.000
#   Component Infrared_Sensor: Schedulable
#     BDR parameters: alpha=0.300, delta=0.000
#   Component Ultraviolet_Sensor: Schedulable
#     BDR parameters: alpha=0.239, delta=7.500
#   Component Thermal_Sensor: Schedulable
#     BDR parameters: alpha=0.510, delta=1.500
#   Component Pressure_Sensor: Schedulable
#     BDR parameters: alpha=0.100, delta=0.000
#   Component Humidity_Sensor: Schedulable
#     BDR parameters: alpha=0.401, delta=0.000
#   Component Temperature_Sensor: Schedulable
#     BDR parameters: alpha=0.595, delta=0.000
#   Component Light_Sensor: Schedulable
#     BDR parameters: alpha=0.203, delta=0.000
#   Component Sound_Sensor: Schedulable
#     BDR parameters: alpha=0.295, delta=0.000
#   Component Vibration_Sensor: Schedulable
#     BDR parameters: alpha=0.107, delta=0.000
#   Component Motion_Sensor: Schedulable
#     BDR parameters: alpha=0.206, delta=0.000
#   Component Acceleration_Sensor: Schedulable
#     BDR parameters: alpha=0.291, delta=7.500
#   Component Gyroscope_Sensor: Schedulable
#     BDR parameters: alpha=0.200, delta=6.000
#   Component Magnetometer_Sensor: Schedulable
#     BDR parameters: alpha=0.105, delta=0.000
#   Component Compass_Sensor: Schedulable
#     BDR parameters: alpha=0.167, delta=7.500
#   Component Altimeter_Sensor: Schedulable
#     BDR parameters: alpha=0.134, delta=7.500
#   Component Barometer_Sensor: Schedulable
#     BDR parameters: alpha=0.474, delta=0.000
#   Component Hygrometer_Sensor: Schedulable
#     BDR parameters: alpha=0.202, delta=0.000
#   Component Anemometer_Sensor: Schedulable
#     BDR parameters: alpha=0.476, delta=1.500
#   Component Rain_Gauge_Sensor: Schedulable
#     BDR parameters: alpha=0.289, delta=7.500
#   Component Snow_Gauge_Sensor: Schedulable
#     BDR parameters: alpha=0.218, delta=7.500
#   Component Thermometer_Sensor: Schedulable
#     BDR parameters: alpha=0.306, delta=7.500
#   Component Pyrometer_Sensor: Schedulable
#     BDR parameters: alpha=0.081, delta=7.500
#   Component Photometer_Sensor: Schedulable
#     BDR parameters: alpha=0.454, delta=0.000
#
# ====================================================================================================
# ANALYSIS RESULTS SUMMARY
# ====================================================================================================
#                     Test Case       Expected         Result Match  Components  Tasks Time (s)
# 0            1-tiny-test-case    Schedulable    Schedulable     ✓           1      2     0.01
# 1           2-small-test-case    Schedulable    Schedulable     ✓           2      9     0.01
# 2          3-medium-test-case    Schedulable    Schedulable     ✓           4     18     0.01
# 3           4-large-test-case    Schedulable    Schedulable     ✓           7     28     0.01
# 4            5-huge-test-case    Schedulable    Schedulable     ✓          18     61     0.01
# 5        6-gigantic-test-case    Schedulable    Schedulable     ✓          34    115     0.02
# 6   7-unschedulable-test-case  Unschedulable  Unschedulable     ✓           6     21     0.01
# 7   8-unschedulable-test-case  Unschedulable    Schedulable     ✗           7     28     0.01
# 8   9-unschedulable-test-case  Unschedulable    Schedulable     ✗          18     61     0.01
# 9  10-unschedulable-test-case  Unschedulable    Schedulable     ✗          34    115     0.02
# Summary results saved to: DRTS_Project-Test-Cases-master\analysis_summary.json
#
# Analysis accuracy: 7/10 (70.0%)
#
# Mismatched test cases:
#   - 8-unschedulable-test-case: Expected Unschedulable, got Schedulable
#   - 9-unschedulable-test-case: Expected Unschedulable, got Schedulable
#   - 10-unschedulable-test-case: Expected Unschedulable, got Schedulable
